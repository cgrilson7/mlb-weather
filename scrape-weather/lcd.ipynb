# %%
from lcd import get_stations_dataframe, get_nearest_stations

# %%
stations = get_stations_dataframe()
stations
# Out:
#     WBAN_ID TRANSMITTAL_ID TRANSMITTAL_ID_TYPE CALL_SIGN FAA_ID WMO_ID  \
# 0     03017           KDEN                ICAO       DEN    DEN  72565
# 2     03812           KAVL                ICAO       AVL    AVL  72315
# 3     03813           KMCN                ICAO       MCN    MCN  72217
# 4     03816           KPAH                ICAO       PAH    PAH  72435
# 5     03820           KAGS                ICAO       AGS    AGS  72218
# ..      ...            ...                 ...       ...    ...    ...
# 266   94849           KAPN                ICAO       APN    APN  72639
# 267   94850           KMQT                ICAO       MQT    MQT  72743
# 268   94860           KGRR                ICAO       GRR    GRR  72635
# 269   94908           KDBQ                ICAO       DBQ    DBQ  72547
# 270   94910           KALO                ICAO       ALO    ALO  72548
#
#     NWSLI_ID COOP_ID     GHCND_ID          CITY  ...   LOCATION_AREA  \
# ...

# %%
stations['LCD_ID']
# Out:
# 0      72565003017
# 2      72315003812
# 3      72217003813
# 4      72435003816
# 5      72218003820
#           ...
# 266    72639094849
# 267    72743094850
# 268    72635094860
# 269    72547094908
# 270    72548094910
# Name: LCD_ID, Length: 260, dtype: object

# %%
get_nearest_stations(stations, 49.446561, -71.097337, 3)
# Out:
#    WBAN_ID TRANSMITTAL_ID TRANSMITTAL_ID_TYPE CALL_SIGN FAA_ID WMO_ID  \
# 87   14607           KCAR                ICAO       CAR    CAR  72712
# 86   14606           KBGR                ICAO       BGR    BGR  72607
# 96   14742           KBTV                ICAO       BTV    BTV  72617
#
#    NWSLI_ID COOP_ID     GHCND_ID        CITY  ... STATE_PROV  \
# 87      CAR  171175  USW00014607     CARIBOU  ...         ME
# 86      BGR  170355  USW00014606      BANGOR  ...         ME
# 96      BTV  431081  USW00014742  BURLINGTON  ...         VT
#
#    FIPS_COUNTRY_CODE NWS_REGION  LAT_DEC  LON_DEC  ELEV_GROUND  \
# 87                US    EASTERN  46.8705 -68.0173        624.0
# 86                US    EASTERN  44.7978 -68.8185        148.0
# 96                US    EASTERN  44.4683 -73.1499        330.0
#
#     ELEV_GROUND_UNIT  UTC_OFFSET       LCD_ID    distance
# 87              FEET          -5  72712014607  366.098807
# 86              FEET          -5  72607014606  544.504835
# ...
